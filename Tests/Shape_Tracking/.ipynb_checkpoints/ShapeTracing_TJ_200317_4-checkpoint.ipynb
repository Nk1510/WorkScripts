# %%
#Image processing imports
import cv2
from skimage import measure

#Graphs & display imports
from matplotlib import pyplot as plt , animation
# %matplotlib inline

#Array and variable maths import
import numpy as np
import pandas as pd
from scipy.interpolate import interp1d
from scipy import signal as sig
from statistics import mean
import math

#GUI imports
from tkinter import filedialog
import tkinter as tk

#file IO imports
import os, sys

sys.path.append(r'C:\Users\Nicolas\Documents\GitHub\Scripts\Python\Librairies_Tim')
sys.path.append(r'C:\Users\Timothe\NasgoyaveOC\Professionnel\TheseUNIC\Scripts\Python\Librairies_Tim')

import pyprind

from LibrairieVideoAna.Commons import smooth

# %%
def rgb2gray(rgb):

    r, g, b = rgb[:,:,0], rgb[:,:,1], rgb[:,:,2]
    #gray = 0.2989 * r + 0.5870 * g + 0.1140 * b
    gray =  (1/3) * r + (1/3) * g + (1/3) * b 
    gray = gray.astype(np.uint8)
    return gray

def Distance(x1,y1,x2,y2):
    dist = math.sqrt((x2 - x1)**2 + (y2 - y1)**2)
    return dist

def Corner_detection(Centroid,Contour):
    mindist = 100000
    DistList = []
    for I in range(np.shape(Contour)[0]):
        dist = Distance(Centroid[0],Centroid[1],Contour[I,0],Contour[I,1])
        DistList.append(dist)
    Difflist = np.diff(DistList,n=1)
    return DistList,Difflist

def Trackers_binarize(image,threshold,claheobj):
    if len(np.shape(image)) > 2:
        image = rgb2gray(image)
    if clahe is not None:
        tempImg = claheobj.apply(image)
    else :
        tempImg = image
    _, binimg = cv2.threshold(tempImg,threshold,255,cv2.THRESH_BINARY)
    return binimg

def df_empty(columns, dtypes, index=None):
    assert len(columns)==len(dtypes)
    df = pd.DataFrame(index=index)
    for c,d in zip(columns, dtypes):
        df[c] = pd.Series(dtype=d)
    return df

# %%
class Trackers_find():
    
    def __init__(self,binImage,areamin,areamax):
        labels = measure.label(binImage, background=1)
        props = measure.regionprops(labels,coordinates='rc')
        
        
        #tracker = {}
        #tracker.update(coords= np.empty((0,2))) 
        
        coords = np.empty((0,2))
        
        #tracker =  pd.DataFrame(columns=['coords','orientation','area','indexs'],dtype=[object,float,int,int])
        
        self.items = df_empty(columns=['coords','orientation','area','indexs'], dtypes=[object,float,int,int])
        
        #self.coords = np.empty((0,2))
        #self.orientation = []
        self.area = []
        self.index = []
        
        for index, label in enumerate(props):
            if label.area > areamin and label.area < areamax :
                if binImage[label.coords[0,0],label.coords[0,1]] != 0:
                    y0, x0 = label.centroid
                    
                    #row =  pd.DataFrame({"A": range(3)})
                    
                    #tracker.coords[found] = [x0, y0]
                    
                    #self.coords = np.append(self.coords,np.array([[x0, y0]]),axis = 0)
                    #tracker.orientation[found] = label.orientation
                    #self.area.append(label.area)
                    #self.index.append(index)
                    
                    self.items = self.items.append({'coords': [x0, y0], 'orientation': label.orientation, 'area': label.area, 'indexs': index}, ignore_index=True)

    
    def RemoveExtremaPos(self, INMindist, INMaxdist):
        
        if self.items.shape[0] > 2:
            #print("entred extrema pos--------------------")
            couplesList = []
            for I in range(self.items.shape[0]):
                for J in range(self.items.shape[0]):
                    if I == J :
                        continue
                    dist = Distance(self.items.coords[I][0], self.items.coords[I][1], self.items.coords[J][0], self.items.coords[J][1])
                    if dist >= INMindist and dist <= INMaxdist :
                        if J > I :
                            
                            tempAppend = [I,J]
                        else :
                            tempAppend = [J,I]
                        stop = 0
                        for T in range(len(couplesList)):
                            if couplesList[T] == tempAppend :
                                stop = 1
                        if stop :
                            break
                        else :
                            #print(f"Distance {dist} for couple {tempAppend}")
                            couplesList.append(tempAppend)

            if len(couplesList) > 0:
                #print(couplesList)
                temp = self.items.copy()
                temp = temp.drop(np.arange(0, self.items.shape[0],1).tolist())
                #display(self.items)
                treated = []
                loc = 0
                for I in range(len(couplesList)):
                    #print(f"couple {couplesList[I]}")
                    
                    if self.items.coords[couplesList[I][0]][1] < self.items.coords[couplesList[I][1]][1] :
                        if couplesList[I][0] not in treated :
                            #print(f"{couplesList[I][0]} = {self.items.coords[couplesList[I][0]][1]} is front")
                            temp.loc[loc] = self.items.loc[couplesList[I][0]]
                            loc = loc + 1
                            treated.append(couplesList[I][0])
                        else :
                            #print(f"{couplesList[I][1]} = {self.items.coords[couplesList[I][1]][1]} is already in dataframe")
                            pass
                        if couplesList[I][1] not in treated :
                            #print(f"{couplesList[I][1]} = {self.items.coords[couplesList[I][1]][1]} is back")
                            temp.loc[loc] = self.items.loc[couplesList[I][1]]
                            loc = loc + 1
                            treated.append(couplesList[I][1])
                        else :
                            #print(f"{couplesList[I][1]} = {self.items.coords[couplesList[I][1]][1]} is already in dataframe")
                            pass
                    else :
                        if couplesList[I][1] not in treated :
                            #print(f"{couplesList[I][1]} = {self.items.coords[couplesList[I][1]][1]} is front")
                            temp.loc[loc] = self.items.loc[couplesList[I][1]]
                            loc = loc + 1
                            treated.append(couplesList[I][1])
                        else :
                            #print(f"{couplesList[I][1]} = {self.items.coords[couplesList[I][1]][1]} is already in dataframe")
                            pass
                        if couplesList[I][0] not in treated :
                            #print(f"{couplesList[I][0]} = {self.items.coords[couplesList[I][0]][1]} is back")
                            temp.loc[loc] = self.items.loc[couplesList[I][0]]
                            loc = loc + 1
                            treated.append(couplesList[I][0])
                        else :
                            #print(f"{couplesList[I][1]} = {self.items.coords[couplesList[I][1]][1]} is already in dataframe")
                            pass
                self.items = temp
                    
                #display(self.items)
                #print(couplesList)
                #print(self.items.shape)
                #self.items = self.items.drop(poplist)
                #print(self.items.shape)
                #isplay(self.items)
                #sys.exit()

    def IntertrackerDistance(self):
        pass
    
    def GetContour(self,binImage):
        
        TempContours = measure.find_contours(binImage, 0.8)
        #print(f"found {np.shape(self.coords)[0]} trackers")
        self.contours = np.full((np.shape(self.coords)[0],2),np.nan,dtype=object)      
        
        
        for I in range(np.shape(self.coords)[0]):
            mindist = 100000
            saveIndex = None
            for n, contour in enumerate(TempContours):
                x_centroid = np.mean(contour[:, 1])
                y_centroid = np.mean(contour[:, 0])
                dist = Distance(x_centroid,y_centroid,self.coords[I,0],self.coords[I,1])
                if mindist > dist :
                    mindist = dist
                    saveIndex = n

            #ARR_cont = measure.subdivide_polygon(contour, degree=2, preserve_ends=True)
            ARR_cont = measure.approximate_polygon(TempContours[saveIndex], tolerance=0.5)

            self.contours[I,:] = [ARR_cont[:,1].tolist(),ARR_cont[:,0].tolist()]

class Trackers_clean():
    
    def __init__(self,TrackerObjDataframe):
        for I in TrackerObjDataframe:
            print(I)
    def AddFrame(self,TrackerObjDataframe)

# %% [markdown]
# # Loading a frame

# %%
folder = r"D:\BehavioralVideos\Whisker_Video\Whisker_Topview\Expect_1\Mouse25\200303_VSD1"
FileList = os.listdir(folder)

video_path = os.path.join(folder,FileList[25])
HandleTOP = cv2.VideoCapture(video_path,cv2.IMREAD_GRAYSCALE)
NumberOfFrames = int(HandleTOP.get(cv2.CAP_PROP_FRAME_COUNT))

# %% [markdown]
#  ## Option with skimage measure and skimage regionprops

# %%
clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(32,32))

HandleTOP.set(cv2.CAP_PROP_POS_FRAMES, 170)
_ , IMG1 = HandleTOP.read()
IMG1 = np.rot90(IMG1,1)
IMG1 = IMG1.astype(np.uint8)

BinIMG1 = Trackers_binarize(IMG1,50,clahe)

fig = plt.figure(figsize = (25,20))
plt.imshow(BinIMG1, cmap='gray', vmin=0, vmax=1)

HandleTOP.set(cv2.CAP_PROP_POS_FRAMES, 0)

colors = ['red','blue','yellow','yellow','yellow','yellow']

bar = pyprind.ProgBar(NumberOfFrames, track_time=True, title='Tracking a video',bar_char='█')

for frameid in range(NumberOfFrames):
    bar.update()
    _ , TempIMG = HandleTOP.read()
    TempIMG = np.rot90(TempIMG,1)
    BinIMG = Trackers_binarize(TempIMG,50,clahe)
    Trk = Trackers_find(BinIMG,500,2000)
            
    elif Trk.items.shape[0] == 2 :
        plt.text(Trk.items.coords[0][0],Trk.items.coords[0][1],f"d {frameid}", color = "gray")
        plt.text(Trk.items.coords[1][0],Trk.items.coords[1][1],f"d {frameid}", color = "gray")
        plt.plot(Trk.items.coords[0][0],Trk.items.coords[0][1],'o',markersize = 7, color = "red")
        plt.plot(Trk.items.coords[1][0],Trk.items.coords[1][1],'o',markersize = 7, color = "blue")   
    else :
        Trk.RemoveExtremaPos(40 , 130)
        for I in range(Trk.items.shape[0]):
            plt.plot(Trk.items.coords[I][0],Trk.items.coords[I][1],'o',markersize = 7, color = colors[I])  
    
    
        
        #plt.plot(Trk.contours[I,0],Trk.contours[I,1],'-',linewidth = 3, color = colors[I])
        #plt.text(Trk.coords[I,0],Trk.coords[I,1],Trk.area[I],fontsize=20,color = 'gray')

plt.savefig("TrackerTrajectory.png")
# Out:
# Tracking a video
# 0% [██████████████████████████████] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:39

# %%
HandleTOP = cv2.VideoCapture(video_path,cv2.IMREAD_GRAYSCALE)
HandleTOP.set(cv2.CAP_PROP_POS_FRAMES, 314)

_ , OTHIMG = HandleTOP.read()

OTHIMG = np.rot90(OTHIMG,1)

BINIMG = Trackers_binarize(OTHIMG,50,clahe)

fig = plt.figure(figsize = (30,30))
plt.imshow(BINIMG, cmap='gray', vmin=0, vmax=1)

# %%
labels = measure.label(thresh2, background=1)
propsa = measure.regionprops(labels)


fig, axs = plt.subplots(3,figsize = (55,60))
axs[0].imshow(thresh2, cmap='gray', vmin=0, vmax=1)


# detection du nombre de labels qui matchent les conditions d'aire pour plotter les images dans différents sous plots
foundlabel = 0

ListX = []
ListY = []

for label in propsa:
        
    if label.area > 500 and label.area < 2000 :
        
        
        
        y0, x0 = label.centroid
        
        ListX.append(x0)
        ListY.append(y0)
        
        orientation = label.orientation
        
        x1 = x0 + math.cos(orientation) * 0.5 * label.minor_axis_length
        y1 = y0 - math.sin(orientation) * 0.5 * label.minor_axis_length
        x2 = x0 - math.sin(orientation) * 0.5 * label.major_axis_length
        y2 = y0 - math.cos(orientation) * 0.5 * label.major_axis_length
        
        #Plotting markers at positions of matching pixels in blue
        #axs[0].plot(label.coords[:,1],label.coords[:,0],'o',color='blue',markersize = 1)
        
        #Plotting markers at positions of centroid of labels, in red
        axs[0].plot(label.centroid[1],label.centroid[0],'o',markersize = 5, color = 'red')
        
        #Plotting major and minor axes in green and purple, respectively
        axs[0].plot([x0,x1],[y0,y1],'-',linewidth = 2, color = 'green')
        axs[0].plot([x0,x2],[y0,y2],'-',linewidth = 2, color = 'purple')
        
        #Plotting text at positions of centroids of label, displaying areas in green
        #axs[0].text(label.centroid[1]+10,label.centroid[0]+10,label.area,fontsize=20,color = 'green')
        
        #Printing more parameters associated with the label found
        print("Label found has major axis :{} minor axis:{} perimeter:{}".format(label.major_axis_length,label.minor_axis_length,label.perimeter))
        
        #Showing an image displaying a cropped image of the matched label, with white (True) as matched pixels, and black(False) as expluded pixels
        #axs[foundlabel+1].imshow(label.filled_image,cmap='gray')
        display(label.filled_image[:,0])
        
        
        foundlabel = foundlabel +1

        
contours = measure.find_contours(thresh2, 0.8)

foundlabel = 0

min = 100000
for n, contour in enumerate(contours):
    x_centroid = np.mean(contour[:, 1])
    y_centroid = np.mean(contour[:, 0])
    for I in range(len(ListX)):
        dist = Distance(x_centroid,y_centroid,ListX[I],ListY[I])
        #print(dist)
        if dist < 10 :
            #ARR_cont = measure.subdivide_polygon(contour, degree=2, preserve_ends=True)
            ARR_cont = measure.approximate_polygon(contour, tolerance=0.5)
            #ARR_cont = contour
            axs[0].plot(ARR_cont[:, 1], ARR_cont[:, 0], linewidth=2)
            axs[0].plot(x_centroid,y_centroid,'o', markersize=4, color = 'gray')
            
            axs[0].text(x_centroid,y_centroid,str(foundlabel+1),fontsize=20,color = 'green')
            
            print(np.shape(ARR_cont))
            ARR_cont_temp = ARR_cont[:,0]
            ARR_cont[:,0] = ARR_cont[:,1]
            ARR_cont[:,1] = ARR_cont_temp
            
            #fs = 44100
            #play_obj = sa.play_buffer(ARR_cont[:, 0], 1, 2, fs)
            #play_obj.wait_done()
            
            peak_heights 
            DistList, Difflist = Corner_detection([x_centroid,y_centroid],ARR_cont)
               
            DistList = smooth(np.asarray(DistList))
            
            X = np.arange(0,np.size(DistList),1)
            Xinterp = np.arange(0,np.size(DistList),0.1)
            f2 = interp1d(X, abs(DistList), kind='cubic', fill_value="extrapolate")
            DistList = f2(Xinterp)
            
            
            Difflist = np.diff(DistList,n=1)
            
            Difflist = smooth(np.asarray(Difflist))
            
            Peaks , values = sig.find_peaks(Difflist, height =  -0.1)
            print(Peaks, values)
            print(type(values))
            
            axs[foundlabel+1].plot(Difflist)
            axs[foundlabel+1].plot(Peaks,values,'o',markersize = 20 , color = 'red')    
            
            foundlabel = foundlabel +1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-3b15740960c9> in <module>
# ----> 1 labels = measure.label(thresh2, background=1)
#       2 propsa = measure.regionprops(labels)
#       3
#       4
#       5 fig, axs = plt.subplots(3,figsize = (55,60))
#
# NameError: name 'thresh2' is not defined

# %% [markdown]
# https://scikit-image.org/docs/dev/api/skimage.measure.html#skimage.measure.regionprops
# Pour plus de paramètres sur regionprops à utiliser : aller à la partie **Notes**

# %%
#Pour utiliser une version table dataframe de pandas : 
propstable = measure.regionprops_table(labels, properties = ('label','centroid','coords','area','major_axis_length','minor_axis_length','image','filled_image'))
datatable = pd.DataFrame(propstable)  
datatable.head()  

display(datatable)
#Pas forcément pklus paratique à utiliser, mais la visualisation du contenu intégral est plus claire

for row in propsa:
    if row.area > 500 and row.area < 2000 :
        print(row.perimeter)
