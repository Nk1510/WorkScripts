# %%
import cv2
from matplotlib import pyplot as plt
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
import numpy as np
from PIL import Image
from PIL import ImageFilter
from matplotlib import animation
from PIL import ImageEnhance

from tkinter import filedialog
import tkinter as tk

import pickle

from os import sys

import matplotlib.pyplot as plt
import argparse

from statistics import mean
import os

# %matplotlib inline

# for loading array 
from scipy.interpolate import interp1d
from scipy.io import loadmat
from scipy import signal as sig
import pandas as pd
import numpy as np
from scipy.signal import filtfilt, butter



sys.path.append(r'C:\Users\Nicolas\Documents\GitHub\WorkScripts')

from LibrairieNico.HitsFctClass import smooth, Easyinterp, diff, calculateNewSize


def FindReferenceSystem2(video_path):
    
    HandleBEHAV = cv2.VideoCapture(video_path, 0)
    length = int(HandleBEHAV.get(cv2.CAP_PROP_FRAME_COUNT))
    
    _ , IMG1 = HandleBEHAV.read()

    linemask2= IMG1[601:602, : , 0]

    linemask2 = np.invert(linemask2)
    linemask2 = linemask2.flatten()

    smoothmask = smooth(linemask2)

    b, a = butter(8, 0.075)
    smoothfiltered = filtfilt(b, a, smoothmask)

    diffmask = np.diff(smoothfiltered,n=1)

    PeaksNO2 , values = sig.find_peaks(diffmask, height = 0.01)

    list1 = []

    if np.size(PeaksNO2) > 1: 

        var_Peaks = 1
        height = 0.01
        TakenHeight = []
        
        while np.size(PeaksNO2) > var_Peaks :
            height = height +0.01
            PeaksNO2_2 , values = sig.find_peaks(diffmask, height)
            
            if np.size(PeaksNO2_2) == 1:
                list1.append(PeaksNO2_2)
                TakenHeight.append(height)
                break
                
    Treshold = (TakenHeight[0])
    Peaks3 = ((list1 [0])  - 20)
    Peaks4 = ((list1 [0])  + 20)
    
    return [Peaks3,Peaks4,Treshold]

# %%
video_path = r"C:\Users\Nicolas\Desktop\Test_Hit\Mouse25_2020-02-07T11.15.51.avi"

HandleBEHAV = cv2.VideoCapture(video_path, 0)


length = int(HandleBEHAV.get(cv2.CAP_PROP_FRAME_COUNT))


_ , IMG1 = HandleBEHAV.read()


Check = IMG1[600:601, : , 0]


#2eme objet
ListObj3 = []
list1 = []

#2eme objet
Reference_peaks2 = FindReferenceSystem2(video_path)

print(Reference_peaks2)
print(Reference_peaks2[2])

#####2eme objet#####

for framne_nb in range(length-1) :


    _ , IMG1 = HandleBEHAV.read()
    
    Check = np.vstack((Check , IMG1[601:602, : , 0]))

    linemask = IMG1[601:602, int(Reference_peaks2[0]):int(Reference_peaks2[1])]

    lineIMG = linemask.copy()
    
    linemask3 = linemask.flatten()
    
    smoothmask = smooth(linemask3)
    
    X = np.arange(0,np.size(smoothmask),1)
    Xinterp = np.arange(0,np.size(smoothmask),0.1)
    f2 = interp1d(X, abs(smoothmask), kind='slinear', fill_value="extrapolate")
    
    raw_interp = f2(Xinterp)
    
    interpol_img = np.reshape(raw_interp,(1, np.shape(raw_interp)[0]))
    interpol_img = np.vstack((interpol_img,interpol_img,interpol_img,interpol_img,interpol_img,interpol_img,interpol_img,interpol_img,interpol_img,interpol_img))

    b, a = butter(8, 0.075)
    smoothfiltered = filtfilt(b, a, raw_interp)

    diffmask = np.diff(smoothfiltered,n=1)
    
    DPeaks , values = sig.find_peaks(abs(diffmask), height = ((Reference_peaks2[2]) /10))
    
    if np.size(DPeaks) == 1:
        ListObj3.append(DPeaks)
        print("frame", framne_nb, "valeur du peak", DPeaks, "condi = 1 obj done")
        continue
        
        
    elif np.size(DPeaks) > 1 : 
        print("frame",framne_nb, "nbr de peak", np.size(DPeaks), "cond > 1")
        var_Peaks = 1
        height = ((Reference_peaks2[2]) /10)
        DPeaks , values = sig.find_peaks(abs(diffmask), height )
        
        while np.size(DPeaks) > var_Peaks :
            height = height +0.01
            DPeaks , values = sig.find_peaks(diffmask, height)

            if np.size(DPeaks) == 1 :
                ListObj3.append(DPeaks)
                print("frame", framne_nb, "nbr de peak", np.size(DPeaks), "cond > 1 done")
        continue 
                
                
    elif np.size(DPeaks) != 1 : 
        print("3eme block")
        var_Peaks = 1
        height = ((Reference_peaks2[2]) /10)


        while np.size(DPeaks) != var_Peaks :
            height = height -0.01
            DPeaks , values = sig.find_peaks(diffmask, height)

            if np.size(DPeaks) == 1:
                ListObj3.append(DPeaks)
                print("peak = 0 corrigé  ", np.size(DPeaks))
                
            else : 
                ListObj3.append(DPeaks)
        break
            
            
print("les Dpeaks", DPeaks)
print("lalistobj3",ListObj3)
print(np.shape(ListObj3))


SD = np.nanstd(ListObj3)
MeanPeaks = np.nanmean(ListObj3)





        
LineFrame = Check[ 0:np.shape(Check)[0] , int(Reference_peaks2[0]):int(Reference_peaks2[1])]
        
#print(np.shape(LineFrame))

Modif = smooth(LineFrame[0,:])

InterpFrame = Easyinterp(Modif)

DiffFrame = np.diff(abs(InterpFrame), n=1)

listmax = [ np.argmin(DiffFrame) ]


for I in range(1,np.shape(LineFrame)[0],1):
    
    Modif = np.vstack( ( Modif, smooth(LineFrame[I,:]) ) )
    InterpFrame = np.vstack( ( InterpFrame , Easyinterp(Modif[I,:] ) ) )
    DiffFrame = np.vstack ( ( DiffFrame , diff(InterpFrame[I,:] ) ) )
    
    listmax.append(np.argmin(DiffFrame[I,:]))
    
    
    
    
    
    
        
    

        






fig = plt.figure(figsize = (35,35))

#print(listmax)
#print(np.shape(Check))
        
        




plt.subplot(221), plt.plot(abs(diffmask))

#plt.subplot(222), plt.plot(abs(smooth(np.asarray(ListObj1)-MeanPeaks)))

plt.subplot(222), plt.plot(ListObj3)
#plt.subplot(222), plt.plot(smoothmask)
#plt.subplot(222), plt.plot(smoothmask)

#plt.xticks(range(0, 540, 20))
#plt.yticks(range(200, 500, 30))
plt.grid(axis="x")



 #plt.subplot(223), plt.imshow(Check, 'jet')

#plt.scatter( int(Reference_peaks2[0]) , 20, s = 1, c = 'red')
#plt.scatter( int(Reference_peaks2[1]) , 20, s = 1,  c = 'red')

#plt.plot( [int(Reference_peaks2[0]),int(Reference_peaks2[0])] , [0,np.shape(Check)[0]], linewidth = 1,  c = 'red')
#plt.plot( [int(Reference_peaks2[1]),int(Reference_peaks2[1])] , [0,np.shape(Check)[0]], linewidth = 1,  c = 'red')

#plt.subplot(224), plt.imshow(Check[   int(Reference_peaks2[1]):int(Reference_peaks2[0])    ,   0:np.shape(Check)[0]   ] , 'jet')
#plt.subplot(224), plt.imshow(Check[ 0:np.shape(Check)[0] , int(Reference_peaks2[1]):int(Reference_peaks2[0])] , 'jet')

plt.subplot(223), plt.imshow(InterpFrame , 'jet')


#plt.subplot(223), plt.imshow(lineIMG, 'gray')


plt.subplot(224), plt.imshow(DiffFrame, 'jet')
plt.plot(listmax,np.arange(0,np.shape(LineFrame)[0],1),'red')


#plt.subplot(224), plt.plot(Listframe2, Listpeaks2, 'o')
#plt.subplot(224), plt.plot(raw_interp)

#plt.xticks(range(0, 500, 20))
#plt.yticks(range(200, 700, 10))

        
        
        
        
        
#fig = plt.figure(figsize = (25,35)

#plt.subplot(221), plt.plot(smoothmask)

#plt.subplot(222), plt.plot(smoothfiltered)

#plt.subplot(223), plt.plot(abs(diffmask))

#plt.subplot(224), plt.imshow(lineIMG, 'gray')

#plt.subplot(224), plt.plot(interpolatedmask)

#plt.subplot(223), plt.imshow(lineIMG, 'gray')

#plt.subplot(224), plt.plot(Listframe, Listpeaks, 'o')
# Out:
# C:\ProgramData\Anaconda3\envs\ArduinoComs\lib\site-packages\scipy\signal\_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# [array([1247], dtype=int64), array([1287], dtype=int64), 1.1100000000000008]
# 1.1100000000000008
# frame 0 nbr de peak 7 cond > 1
# frame 0 nbr de peak 1 cond > 1 done
# frame 1 valeur du peak [324] condi = 1 obj done
# frame 2 nbr de peak 2 cond > 1
# frame 3 nbr de peak 3 cond > 1
# frame 4 valeur du peak [579] condi = 1 obj done
# frame 5 nbr de peak 3 cond > 1
# frame 6 nbr de peak 4 cond > 1
# frame 6 nbr de peak 1 cond > 1 done
# frame 7 nbr de peak 2 cond > 1
# frame 8 nbr de peak 6 cond > 1
# frame 8 nbr de peak 1 cond > 1 done
# frame 9 valeur du peak [492] condi = 1 obj done
# frame 10 nbr de peak 2 cond > 1
# frame 11 nbr de peak 4 cond > 1
# frame 12 nbr de peak 2 cond > 1
# frame 13 nbr de peak 4 cond > 1
# frame 13 nbr de peak 1 cond > 1 done
# frame 14 nbr de peak 4 cond > 1
# frame 15 nbr de peak 3 cond > 1
# frame 15 nbr de peak 1 cond > 1 done
# frame 16 nbr de peak 3 cond > 1
# frame 17 nbr de peak 2 cond > 1
# frame 18 nbr de peak 3 cond > 1
# frame 19 nbr de peak 4 cond > 1
# frame 20 nbr de peak 5 cond > 1
# frame 20 nbr de peak 1 cond > 1 done
# frame 21 nbr de peak 5 cond > 1
# frame 21 nbr de peak 1 cond > 1 done
# frame 22 nbr de peak 4 cond > 1
# frame 22 nbr de peak 1 cond > 1 done
# frame 23 nbr de peak 5 cond > 1
# frame 23 nbr de peak 1 cond > 1 done
# frame 24 nbr de peak 4 cond > 1
# frame 25 nbr de peak 3 cond > 1
# frame 26 valeur du peak [554] condi = 1 obj done
# frame 27 nbr de peak 5 cond > 1
# frame 27 nbr de peak 1 cond > 1 done
# frame 28 nbr de peak 3 cond > 1
# frame 29 nbr de peak 2 cond > 1
# frame 30 nbr de peak 3 cond > 1
# frame 31 nbr de peak 3 cond > 1
# frame 32 nbr de peak 4 cond > 1
# frame 32 nbr de peak 1 cond > 1 done
# frame 33 nbr de peak 2 cond > 1
# frame 34 nbr de peak 2 cond > 1
# frame 35 nbr de peak 2 cond > 1
# frame 36 nbr de peak 7 cond > 1
# frame 36 nbr de peak 1 cond > 1 done
# frame 37 nbr de peak 2 cond > 1
# frame 38 nbr de peak 3 cond > 1
# frame 39 valeur du peak [314] condi = 1 obj done
# frame 40 nbr de peak 4 cond > 1
# frame 40 nbr de peak 1 cond > 1 done
# frame 41 nbr de peak 2 cond > 1
# frame 42 nbr de peak 3 cond > 1
# frame 43 nbr de peak 3 cond > 1
# frame 44 nbr de peak 4 cond > 1
# frame 45 nbr de peak 2 cond > 1
# frame 46 nbr de peak 2 cond > 1
# frame 47 nbr de peak 3 cond > 1
# frame 48 nbr de peak 4 cond > 1
# frame 48 nbr de peak 1 cond > 1 done
# frame 49 nbr de peak 5 cond > 1
# frame 49 nbr de peak 1 cond > 1 done
# frame 50 nbr de peak 2 cond > 1
# frame 51 nbr de peak 3 cond > 1
# frame 52 nbr de peak 3 cond > 1
# frame 53 nbr de peak 2 cond > 1
# frame 54 nbr de peak 4 cond > 1
# frame 55 nbr de peak 5 cond > 1
# frame 55 nbr de peak 1 cond > 1 done
# frame 56 nbr de peak 3 cond > 1
# frame 57 nbr de peak 2 cond > 1
# frame 58 valeur du peak [325] condi = 1 obj done
# frame 59 nbr de peak 5 cond > 1
# frame 60 nbr de peak 3 cond > 1
# frame 61 nbr de peak 3 cond > 1
# frame 62 nbr de peak 2 cond > 1
# frame 63 nbr de peak 4 cond > 1
# frame 64 nbr de peak 5 cond > 1
# frame 64 nbr de peak 1 cond > 1 done
# frame 65 nbr de peak 2 cond > 1
# frame 66 valeur du peak [578] condi = 1 obj done
# frame 67 valeur du peak [608] condi = 1 obj done
# frame 68 nbr de peak 4 cond > 1
# frame 69 nbr de peak 5 cond > 1
# frame 70 nbr de peak 3 cond > 1
# frame 71 nbr de peak 6 cond > 1
# frame 71 nbr de peak 1 cond > 1 done
# frame 72 nbr de peak 3 cond > 1
# frame 73 nbr de peak 4 cond > 1
# frame 74 nbr de peak 3 cond > 1
# frame 75 nbr de peak 2 cond > 1
# frame 76 nbr de peak 2 cond > 1
# frame 77 nbr de peak 4 cond > 1
# frame 77 nbr de peak 1 cond > 1 done
# frame 78 nbr de peak 3 cond > 1
# frame 79 nbr de peak 3 cond > 1
# frame 80 nbr de peak 2 cond > 1
# frame 81 nbr de peak 2 cond > 1
# frame 82 nbr de peak 3 cond > 1
# frame 83 nbr de peak 4 cond > 1
# frame 84 valeur du peak [557] condi = 1 obj done
# frame 85 nbr de peak 2 cond > 1
# frame 86 nbr de peak 2 cond > 1
# frame 87 valeur du peak [464] condi = 1 obj done
# frame 88 nbr de peak 3 cond > 1
# frame 89 nbr de peak 4 cond > 1
# frame 90 nbr de peak 4 cond > 1
# frame 91 nbr de peak 7 cond > 1
# frame 91 nbr de peak 1 cond > 1 done
# frame 92 nbr de peak 2 cond > 1
# frame 93 nbr de peak 3 cond > 1
# frame 94 nbr de peak 3 cond > 1
# frame 95 nbr de peak 5 cond > 1
# frame 96 nbr de peak 4 cond > 1
# frame 96 nbr de peak 1 cond > 1 done
# frame 97 nbr de peak 2 cond > 1
# frame 98 nbr de peak 2 cond > 1
# frame 99 valeur du peak [429] condi = 1 obj done
# frame 100 nbr de peak 3 cond > 1
# frame 101 nbr de peak 3 cond > 1
# frame 102 nbr de peak 3 cond > 1
# frame 102 nbr de peak 1 cond > 1 done
# frame 103 nbr de peak 2 cond > 1
# frame 104 nbr de peak 4 cond > 1
# frame 105 nbr de peak 2 cond > 1
# frame 106 nbr de peak 3 cond > 1
# frame 107 valeur du peak [422] condi = 1 obj done
# frame 108 nbr de peak 4 cond > 1
# frame 108 nbr de peak 1 cond > 1 done
# frame 109 valeur du peak [561] condi = 1 obj done
# frame 110 valeur du peak [419] condi = 1 obj done
# frame 111 nbr de peak 2 cond > 1
# frame 112 nbr de peak 4 cond > 1
# frame 113 nbr de peak 2 cond > 1
# frame 114 nbr de peak 2 cond > 1
# frame 115 nbr de peak 4 cond > 1
# frame 115 nbr de peak 1 cond > 1 done
# frame 116 valeur du peak [196] condi = 1 obj done
# frame 117 nbr de peak 3 cond > 1
# frame 117 nbr de peak 1 cond > 1 done
# frame 118 nbr de peak 3 cond > 1
# frame 119 nbr de peak 3 cond > 1
# frame 120 valeur du peak [579] condi = 1 obj done
# frame 121 valeur du peak [492] condi = 1 obj done
# frame 122 nbr de peak 4 cond > 1
# frame 123 nbr de peak 6 cond > 1
# frame 123 nbr de peak 1 cond > 1 done
# frame 124 valeur du peak [439] condi = 1 obj done
# frame 125 nbr de peak 2 cond > 1
# frame 126 nbr de peak 4 cond > 1
# frame 127 nbr de peak 4 cond > 1
# frame 127 nbr de peak 1 cond > 1 done
# frame 128 nbr de peak 4 cond > 1
# frame 129 nbr de peak 4 cond > 1
# frame 130 valeur du peak [114] condi = 1 obj done
# frame 131 nbr de peak 3 cond > 1
# frame 132 nbr de peak 2 cond > 1
# frame 133 nbr de peak 3 cond > 1
# frame 134 nbr de peak 4 cond > 1
# frame 135 nbr de peak 3 cond > 1
# frame 136 nbr de peak 3 cond > 1
# frame 137 nbr de peak 2 cond > 1
# frame 138 valeur du peak [485] condi = 1 obj done
# frame 139 nbr de peak 7 cond > 1
# frame 139 nbr de peak 1 cond > 1 done
# frame 140 valeur du peak [443] condi = 1 obj done
# frame 141 nbr de peak 2 cond > 1
# 3eme block
# peak = 0 corrigé en  1
# les Dpeaks [25]
# lalistobj3 [array([266], dtype=int64), array([324], dtype=int64), array([579], dtype=int64), array([357], dtype=int64), array([148], dtype=int64), array([492], dtype=int64), array([72], dtype=int64), array([112], dtype=int64), array([255], dtype=int64), array([155], dtype=int64), array([271], dtype=int64), array([7], dtype=int64), array([554], dtype=int64), array([24], dtype=int64), array([357], dtype=int64), array([73], dtype=int64), array([314], dtype=int64), array([977], dtype=int64), array([24], dtype=int64), array([18], dtype=int64), array([268], dtype=int64), array([325], dtype=int64), array([79], dtype=int64), array([578], dtype=int64), array([608], dtype=int64), array([20], dtype=int64), array([27], dtype=int64), array([557], dtype=int64), array([464], dtype=int64), array([21], dtype=int64), array([789], dtype=int64), array([429], dtype=int64), array([26], dtype=int64), array([422], dtype=int64), array([797], dtype=int64), array([561], dtype=int64), array([419], dtype=int64), array([29], dtype=int64), array([196], dtype=int64), array([26], dtype=int64), array([579], dtype=int64), array([492], dtype=int64), array([260], dtype=int64), array([439], dtype=int64), array([18], dtype=int64), array([114], dtype=int64), array([485], dtype=int64), array([22], dtype=int64), array([443], dtype=int64), array([], dtype=int64), array([], dtype=int64), array([], dtype=int64), array([], dtype=int64), array([], dtype=int64), array([], dtype=int64), array([], dtype=int64), array([], dtype=int64), array([], dtype=int64), array([], dtype=int64), array([], dtype=int64), array([], dtype=int64), array([], dtype=int64), array([], dtype=int64), array([], dtype=int64), array([], dtype=int64), array([], dtype=int64), array([], dtype=int64), array([], dtype=int64), array([25], dtype=int64)]
# (69,)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-6430095a77e0> in <module>
#     160 #plt.subplot(222), plt.plot(abs(smooth(np.asarray(ListObj1)-MeanPeaks)))
#     161
# --> 162 plt.subplot(222), plt.plot(ListObj3)
#     163 #plt.subplot(222), plt.plot(smoothmask)
#     164 #plt.subplot(222), plt.plot(smoothmask)
#
# C:\ProgramData\Anaconda3\envs\ArduinoComs\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2761     return gca().plot(
#    2762         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2763         is not None else {}), **kwargs)
#    2764
#    2765
#
# C:\ProgramData\Anaconda3\envs\ArduinoComs\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1646         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1647         for line in lines:
# -> 1648             self.add_line(line)
#    1649         self._request_autoscale_view(scalex=scalex, scaley=scaley)
#    1650         return lines
#
# C:\ProgramData\Anaconda3\envs\ArduinoComs\lib\site-packages\matplotlib\axes\_base.py in add_line(self, line)
#    1848             line.set_clip_path(self.patch)
#    1849
# -> 1850         self._update_line_limits(line)
#    1851         if not line.get_label():
#    1852             line.set_label('_line%d' % len(self.lines))
#
# C:\ProgramData\Anaconda3\envs\ArduinoComs\lib\site-packages\matplotlib\axes\_base.py in _update_line_limits(self, line)
#    1870         Figures out the data limit of the given line, updating self.dataLim.
#    1871         """
# -> 1872         path = line.get_path()
#    1873         if path.vertices.size == 0:
#    1874             return
#
# C:\ProgramData\Anaconda3\envs\ArduinoComs\lib\site-packages\matplotlib\lines.py in get_path(self)
#    1025         """
#    1026         if self._invalidy or self._invalidx:
# -> 1027             self.recache()
#    1028         return self._path
#    1029
#
# C:\ProgramData\Anaconda3\envs\ArduinoComs\lib\site-packages\matplotlib\lines.py in recache(self, always)
#     673         if always or self._invalidy:
#     674             yconv = self.convert_yunits(self._yorig)
# --> 675             y = _to_unmasked_float_array(yconv).ravel()
#     676         else:
#     677             y = self._y
#
# C:\ProgramData\Anaconda3\envs\ArduinoComs\lib\site-packages\matplotlib\cbook\__init__.py in _to_unmasked_float_array(x)
#    1315         return np.ma.asarray(x, float).filled(np.nan)
#    1316     else:
# -> 1317         return np.asarray(x, float)
#    1318
#    1319
#
# C:\ProgramData\Anaconda3\envs\ArduinoComs\lib\site-packages\numpy\core\numeric.py in asarray(a, dtype, order)
#     499
#     500     """
# --> 501     return array(a, dtype, copy=False, order=order)
#     502
#     503
#
# ValueError: setting an array element with a sequence.
