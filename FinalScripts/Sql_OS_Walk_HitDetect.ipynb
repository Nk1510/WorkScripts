# %%
# -*- coding: utf-8 -*-
"""
Created on Tue Mar  3 08:59:19 2020

@author: Timothe
"""

import sys, os

sys.path.append(r"C:\Users\nkhefif\Desktop\Scripts\Python")

import sqlalchemy as sql
from LibrairieVideoAna.VideoAna import GetSessionFolder
from LibrairieNico.HitsDetection import HitDetection


connect_string = 'mysql+mysqlconnector://RedCentral:21User*91!@157.136.60.198/maze?use_pure=True'
sql_engine = sql.create_engine(connect_string)

LocalPath = r"D:\Eugenia\Nico\DATA"

video_path = os.path.join(LocalPath, GetSessionFolder(1505, sql_engine, FOV='topView'))

print(video_path)
#⌂path = r"\\157.136.60.11\EqShulz\Timothe\BehavioralVideos\Whisker_Video\Whisker_Topview\Expect_1\Mouse25\200213_2"

for root, dirs, files in os.walk(video_path, topdown=True):
    for name in files:
        if name[-4:] == '.avi':
            #print(os.path.join(root, name))
            HitDetection(os.path.join(root, name))
            print("c'est good")
# Out:
#    session_id        session_date  mouse_number batch_name
# 0        1505 2020-02-10 15:05:32            25   Expect_1
# 1        1520 2020-02-10 19:52:36            25   Expect_1
# D:\Eugenia\Nico\DATA\BehavioralVideos\Whisker_Video\Whisker_Topview\Expect_1\Mouse25\200210_1
# La liste des frames inclues dans l'interval est : [132, 137, 150, 156]  video Mouse25_2020-02-10T15.05.58
# c'est good
# La liste des frames inclues dans l'interval est : [156]  video Mouse25_2020-02-10T15.06.05
# c'est good
# La liste des frames inclues dans l'interval est : [128]  video Mouse25_2020-02-10T15.06.11
# c'est good
# La liste des frames inclues dans l'interval est : [135, 148]  video Mouse25_2020-02-10T15.06.17
# c'est good
# La liste des frames inclues dans l'interval est : [130]  video Mouse25_2020-02-10T15.06.22
# c'est good
# La liste des frames inclues dans l'interval est : []  video Mouse25_2020-02-10T15.06.28
# c'est good
# ...
