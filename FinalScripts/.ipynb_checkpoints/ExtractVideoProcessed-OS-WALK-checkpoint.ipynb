# %%
import cv2
from matplotlib import pyplot as plt
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
import numpy as np
from PIL import Image
from PIL import ImageFilter
from matplotlib import animation
from PIL import ImageEnhance
import pyprind
import os
from tkinter import filedialog
import tkinter as tk


# %matplotlib inline

# %%
def rgb2gray(rgb):

    r, g, b = rgb[:,:,0], rgb[:,:,1], rgb[:,:,2]
    #gray = 0.2989 * r + 0.5870 * g + 0.1140 * b
    gray =  (1/3) * r + (1/3) * g + (1/3) * b 
    gray = gray.astype(np.uint8)
    return gray


def Extract(inputBASE):

    HandleBEHAV = cv2.VideoCapture(inputBASE)
    length = int(HandleBEHAV.get(cv2.CAP_PROP_FRAME_COUNT))

    _ , img1 = HandleBEHAV.read()
    size = np.shape(img1)
    #print(size)
    height = size[0]
    width = size[1]
    #print(width,height)
    #print(HandleBEHAV)             
               
                

    globalpath = os.path.dirname(currentfile)
    basefile = os.path.basename(currentfile)[:-4]

    outputpath = os.path.join(globalpath, basefile + "_processed_")

    
                    #tests

                    #fourcc = cv2.VideoWriter_fourcc(*'')
                    #out = cv2.VideoWriter(outputpath, fourcc, 30.0, (height, width))

                    #methode pour tester différents codex et etx :

                    #extensions = ['avi', 'mp4','mov']
                    #codecs = ['MJPG', 'H264', 'DIVX', 'XVID', 'X264', '40  ']

    extensions = ['avi']
    codecs = ['MJPG']

    listHolders = []

    for ext in extensions:
        for codec in codecs:
            savepath = outputpath + "_%s.%s" % (codec.strip(' '), ext)

            try:

                fourcc = cv2.VideoWriter_fourcc(*codec)

                listHolders.append(cv2.VideoWriter(savepath, fourcc, 30.0, (width, height), 1))

            except Exception as e:
                pass



    bar = pyprind.ProgBar(length-1,bar_char='▓')

    for framne_nb in range(length-1) :

        _ , BEHi = HandleBEHAV.read()
        #BEHi = rgb2gray(BEHi)
        #BEHi = cv2.fastNlMeansDenoising(BEHi)

        BEHi = Image.fromarray(BEHi)
        BEHi = BEHi.filter(ImageFilter.EDGE_ENHANCE)
        BEHi = np.array(BEHi)

        #_ , BEHi = HandleBEHAV.read()
        BEHi = rgb2gray(BEHi)
        BEHi = cv2.fastNlMeansDenoising(BEHi)
        
        bar.update()

        for holder in listHolders:
                        #niveaux de gris
                        #holder.write(BEHi)

                        #couleur
            BEHi = np.stack((BEHi, BEHi, BEHi),axis=-1)
            holder.write(BEHi)


        if framne_nb >= 550 :
            break


                        #print(np.shape(BEHi))

    HandleBEHAV.release()

    for holder in listHolders:
        holder.release()

    print("Done {} frames".format(framne_nb))

# %%
######################################################
        
        

root = tk.Tk()

CHOOSE_INPUT_PATH_ON_START =  1


inputBASE = r"C:\Users\nkhefif\Desktop\WhiskiTestsVideo\26_02_20_test_200218_2_M24"

#outputBASE = r"C:\Users\Nicolas\Desktop\Extraits CMPT"
#outputBASE = os.path.join(globalpath, basefile + "_processed")
#outputBASE(currentfile)



if CHOOSE_INPUT_PATH_ON_START :
    
    inputBASE = filedialog.askdirectory(parent=root, initialdir=inputBASE, title='Choose videos to process')
    

for root, dir, files in os.walk(inputBASE):
    print(files)
    print(root)
    for file in files:
        print(file)
        if file.endswith('.avi'):
            
            currentfile = os.path.join(root, file)
            #currentfile = os.path.normpath(currentfile)
            print(currentfile)
            Extract(currentfile)
            os.system ('myscript.py {}'.format(root + '\\' + file))
            
          
    
    
    #for subdir in dir:
        
        #inputSUB= os.path.join(root,subdir)
        #ListOfFiles = Foldersearch(inputSUB,TrialFileNAme+".avi")
        
    #print(ListOfFiles)
            
########
            #PathTobethaviorVideo = (inputBASE + '\\' + file )


#######
# Out:
# ['Mouse25_2020-03-03T11.50.28.avi', 'Mouse25_2020-03-03T11.50.28_processed_denoised_after_edgeEHN_MJPG.avi', 'Mouse25_2020-03-03T11.50.28_processed_MJPG_no_parameter.avi', 'Mouse25_2020-03-03T11.50.28_processed_no_denoised_MJPG.avi', 'Mouse25_2020-03-03T11.51.18.avi', 'Mouse25_2020-03-03T11.51.31.avi']
# D:/Eugenia/Nico/DATA/TestWhiskTrack_Closeup_Topview/Mouse25/Topview/VSD2_recorded_noExpect
# Mouse25_2020-03-03T11.50.28.avi
# D:/Eugenia/Nico/DATA/TestWhiskTrack_Closeup_Topview/Mouse25/Topview/VSD2_recorded_noExpect\Mouse25_2020-03-03T11.50.28.avi
# 0% [▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓] 100% | ETA: 00:00:00
# Done 498 frames
# Mouse25_2020-03-03T11.50.28_processed_denoised_after_edgeEHN_MJPG.avi
# D:/Eugenia/Nico/DATA/TestWhiskTrack_Closeup_Topview/Mouse25/Topview/VSD2_recorded_noExpect\Mouse25_2020-03-03T11.50.28_processed_denoised_after_edgeEHN_MJPG.avi
# Total time elapsed: 00:11:12
# 0% [▓▓▓▓▓▓                        ] 100% | ETA: 00:09:09
