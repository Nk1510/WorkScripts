# %%
import mysql.connector
import math
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import calendar
import datetime
from datetime import timedelta
import random
import sys, os
import scipy as sp
from scipy import stats
from scipy.interpolate import make_interp_spline, BSpline
import cv2
cap = cv2.VideoCapture('G:\3d scanner\2.mmv')

import pandas as pd
import sqlalchemy as sql

sys.path.append(r'C:\Users\Timothe\NasgoyaveOC\Professionnel\ThèseUNIC\CodeAnalyses\Comportement\BehavioralPerformances')

connect_string = 'mysql+mysqlconnector://RedCentral:21User*91!@157.136.60.198/maze?use_pure=True'
sql_engine = sql.create_engine(connect_string)

#try:
    #connect_string = 'mysql+mysqlconnector://RedCentral:21User*91!@157.136.60.198/maze'
    #sql_engine = sql.create_engine(connect_string)
#except :

# %%
result = pd.read_sql_query("select * from mouses", sql_engine)

# %%
query = ("""
SELECT mouse_number, session_id, session_date FROM maze.mouses_sessions AS MS
INNER JOIN mouses AS MO
ON MO.mouses_id = MS.mouses_id
where training_set_id = 65
""")
result = pd.read_sql_query(query, sql_engine)
pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
display(result)
# Out:
#     mouse_number  session_id        session_date
# 0   21            1622       2020-02-24 15:12:24
# 1   21            1623       2020-02-24 15:52:50
# 2   21            1624       2020-02-24 16:26:57
# 3   21            1625       2020-02-24 16:55:08
# 4   24            1629       2020-02-25 13:17:15
# 5   24            1630       2020-02-25 13:40:01
# 6   24            1631       2020-02-25 14:36:02
# 7   24            1632       2020-02-25 14:59:33
# 8   24            1633       2020-02-25 15:46:22
# 9   25            1654       2020-03-03 11:19:18
# 10  25            1655       2020-03-03 11:25:33
# 11  25            1656       2020-03-03 11:48:54
# 12  25            1657       2020-03-03 12:09:22

# %%
query = ("""
    SELECT mouse_number, MS.session_id, timestamp, SD.event_value, event_origin FROM mouses_sessions as MS
	
    INNER JOIN session_detail as SD
	ON MS.session_id = SD.session_id
    
	INNER JOIN event_def as ED
	ON SD.event_value = ED.event_value
    
	INNER JOIN mouses as MO 
	ON MO.mouses_id = MS.mouses_id
    
	INNER JOIN training_set_def as TS
	ON TS.training_set_id = MS.training_set_id
    
    where MS.session_id = {0} and SD.event_value in (50,60,255)
    """)

# %%
SessionID = 1656
result = pd.read_sql_query(query.format(SessionID), sql_engine)

display(result)
# Out:
#      mouse_number  session_id  timestamp  event_value         event_origin
# 0    25            1656        0          60           StartCentralEvent
# 1    25            1656        0          255          CentralAlleyTrigger
# 2    25            1656        42319      60           StartCentralEvent
# 3    25            1656        42320      255          CentralAlleyTrigger
# 4    25            1656        85442      60           StartCentralEvent
# 5    25            1656        85443      255          CentralAlleyTrigger
# 6    25            1656        99620      60           StartCentralEvent
# 7    25            1656        99621      255          CentralAlleyTrigger
# 8    25            1656        113589     50           StartVSDRecord
# 9    25            1656        113589     60           StartCentralEvent
# 10   25            1656        113590     255          CentralAlleyTrigger
# 11   25            1656        162775     50           StartVSDRecord
# ...

# %%
data = [[1, 'NaN']]
TableEventNumbers = pd.DataFrame(data, columns = ['Trial', 'VSD'])

Trialnb = 2
VSD = 1



for index, row in result.iterrows():

    if row['event_value'] == 255 :
        TableEventNumbers.at[Trialnb-1, 'Trial'] = Trialnb
        Trialnb = Trialnb + 1
        #print(index)
    if row['event_value'] == 50 :
        TableEventNumbers.at[Trialnb-1, 'VSD'] = "VSD recording n° " + str(VSD)
        VSD = VSD +1
    
        



        
display(TableEventNumbers)
# Out:
#      Trial                  VSD
# 0    1.0    NaN
# 1    2.0    NaN
# 2    3.0    NaN
# 3    4.0    NaN
# 4    5.0    NaN
# 5    6.0    VSD recording n° 1
# 6    7.0    VSD recording n° 2
# 7    8.0    VSD recording n° 3
# 8    9.0    VSD recording n° 4
# 9    10.0   VSD recording n° 5
# 10   11.0   VSD recording n° 6
# 11   12.0   VSD recording n° 7
# 12   13.0   VSD recording n° 8
# 13   14.0   VSD recording n° 9
# 14   15.0   VSD recording n° 10
# 15   16.0   VSD recording n° 11
# 16   17.0   VSD recording n° 12
# 17   18.0   VSD recording n° 13
# 18   19.0   VSD recording n° 14
# 19   20.0   VSD recording n° 15
# 20   21.0   VSD recording n° 16
# 21   22.0   VSD recording n° 17
# 22   23.0   VSD recording n° 18
# 23   24.0   VSD recording n° 19
# 24   25.0   VSD recording n° 20
# 25   26.0   VSD recording n° 21
# 26   27.0   VSD recording n° 22
# 27   28.0   VSD recording n° 23
# 28   29.0   VSD recording n° 24
# 29   30.0   VSD recording n° 25
# 30   31.0   VSD recording n° 26
# ...
